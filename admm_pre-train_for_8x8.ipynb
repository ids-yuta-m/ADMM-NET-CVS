# %%
import torch
print(torch.cuda.is_available())
print(torch.__version__)
print(torch.version.cuda)
# Out:
# True
# 2.3.1
# 12.1

# %%
from torch.utils.data import Dataset
import os
import torch
import torch.nn as nn
import math
from torch.autograd import Function
import scipy.io as scio
from scipy import io

class Imgdataset(Dataset):

    def __init__(self, path):
        super(Imgdataset, self).__init__()
        self.data = []
        if os.path.exists(path):
            groung_truth_path = path + '/gt_gray_8x8_rand'

            if os.path.exists(groung_truth_path):
                groung_truth = os.listdir(groung_truth_path)
                self.data = [{'groung_truth': groung_truth_path + '/' + groung_truth[i]} for i in
                             range(len(groung_truth))]
            else:
                raise FileNotFoundError('path doesnt exist!')
        else:
            raise FileNotFoundError('path doesnt exist!')

    def __getitem__(self, index):
        groung_truth = self.data[index]["groung_truth"]

        gt = scio.loadmat(groung_truth)
        if "patch" in gt:
            gt = torch.from_numpy(gt['patch'])
        elif "patch_save_gray" in gt:
            gt = torch.from_numpy(gt['patch_save_gray'])
        elif "p1" in gt:
            gt = torch.from_numpy(gt['p1'] / 255)
        elif "p2" in gt:
            gt = torch.from_numpy(gt['p2'] / 255)
        elif "p3" in gt:
            gt = torch.from_numpy(gt['p3'] / 255)
            
        #print(gt.shape)
        #gt = gt.permute(2, 0, 1)

        return gt

    def __len__(self):

        return len(self.data)

# %%
import torch
import torch.nn as nn

class double_conv(nn.Module):

    def __init__(self, in_channels, out_channels):
        super(double_conv, self).__init__()
        self.d_conv = nn.Sequential(
            nn.Conv2d(in_channels, out_channels, 3, padding=1),
            nn.ReLU(inplace=True),
            nn.Conv2d(out_channels, out_channels, 3, padding=1),
            nn.ReLU(inplace=True)
        )

    def forward(self, x):
        x = self.d_conv(x)
        return x

class Unet(nn.Module):

    def __init__(self,in_ch, out_ch):
        super(Unet, self).__init__()
                
        self.dconv_down1 = double_conv(in_ch, 32)
        self.dconv_down2 = double_conv(32, 64)

        self.maxpool = nn.MaxPool2d(2)
    
        self.upsample = nn.Sequential(
            nn.ConvTranspose2d(64, 32, kernel_size=2, stride=2),
            nn.ReLU(inplace=True)
        )
        self.dconv_up = double_conv(32 + 32, 32)
        
        self.conv_last = nn.Conv2d(32, out_ch, 1)
        self.afn_last = nn.Tanh()
        
        
    def forward(self, x):
        inputs = x
        
        # エンコーダーパス
        conv1 = self.dconv_down1(x)      # 8x8 -> 8x8
        x = self.maxpool(conv1)          # 8x8 -> 4x4
        
        # ボトルネック
        conv2 = self.dconv_down2(x)      # 4x4 -> 4x4
        
        # デコーダーパス
        x = self.upsample(conv2)         # 4x4 -> 8x8
        x = torch.cat([x, conv1], dim=1) # スキップ接続
        x = self.dconv_up(x)
        
        # 出力
        x = self.conv_last(x)
        x = self.afn_last(x)
        out = x + inputs
        
        return out
    
class double_conv3d(nn.Module):

    def __init__(self, in_channels, out_channels):
        super(double_conv3d, self).__init__()
        self.d_conv = nn.Sequential(
            nn.Conv3d(in_channels, out_channels, 3, padding=1),
            nn.ReLU(inplace=True),
            nn.Conv3d(out_channels, out_channels, 3, padding=1),
            nn.ReLU(inplace=True)
        )

    def forward(self, x):
        x = self.d_conv(x)
        return x

class Unet3d(nn.Module):

    def __init__(self,in_ch, out_ch):
        super(Unet3d, self).__init__()
                
        self.dconv_down1 = double_conv3d(in_ch, 32)
        self.dconv_down2 = double_conv3d(32, 64)
        self.dconv_down3 = double_conv3d(64, 128)       

        self.maxpool = nn.MaxPool3d(2)
        self.upsample2 = nn.Sequential(
            nn.ConvTranspose3d(128, 64, kernel_size=2, stride=2),
            nn.ReLU(inplace=True)
        )
        self.upsample1 = nn.Sequential(
            nn.ConvTranspose3d(64, 32, kernel_size=2, stride=2),
            nn.ReLU(inplace=True)
        )
        self.dconv_up2 = double_conv3d(64 + 64, 64)
        self.dconv_up1 = double_conv3d(32 + 32, 32)
        
        self.conv_last = nn.Conv3d(32, out_ch, 1)
        self.afn_last = nn.Tanh()
        
        
    def forward(self, x):
        inputs = x
        #print('inputsize:{}'.format(x.shape))
        conv1 = self.dconv_down1(x)
        #print('conv1size:{}'.format(conv1.shape))
        
        x = self.maxpool(conv1)
        #print('maxpoolsize:{}'.format(x.shape))
        

        conv2 = self.dconv_down2(x)
        #print('conv2size:{}'.format(conv2.shape))
        
        x = self.maxpool(conv2)
        #print('maxpool2size:{}'.format(x.shape))
        
        conv3 = self.dconv_down3(x)
        #print('conv3size:{}'.format(conv3.shape))

        
        x = self.upsample2(conv3)
        #print('x1:{}'.format(x.shape))        
        x = torch.cat([x, conv2], dim=1)
        #print('x2:{}'.format(x.shape))        
        x = self.dconv_up2(x)
        #print('x3:{}'.format(x.shape))        
        x = self.upsample1(x)        
        #print('x4:{}'.format(x.shape))        
        x = torch.cat([x, conv1], dim=1)      
        #print('x5:{}'.format(x.shape))         

        x = self.dconv_up1(x)  
        #print('x6:{}'.format(x.shape))        
        
        x = self.conv_last(x)
        x = self.afn_last(x)
        out = x + inputs
        
        return out

# %%
import torch
import scipy.io as scio
import numpy as np
from torch.utils.data import Dataset
import os
import torch.nn as nn
import math
from torch.autograd import Function
from scipy import io


# シャッタパターン読み込み
def generate_masks(mask_path,mask_name):
    mask = scio.loadmat(mask_path + '/' + mask_name)
    mask = mask['ExpPtn']
    #print(mask.shape)
    mask = np.transpose(mask, [2, 0, 1])
    mask_s = np.sum(mask, axis=0)
    index = np.where(mask_s == 0)
    mask_s[index] = 1
    mask_s = mask_s.astype(np.uint8)
    mask = torch.from_numpy(mask)
    mask = mask.float()
    mask = mask.cuda()
    mask_s = torch.from_numpy(mask_s)
    mask_s = mask_s.float()
    mask_s = mask_s.cuda()
    return mask, mask_s

def time2file_name(time):
    year = time[0:4]
    month = time[5:7]
    day = time[8:10]
    hour = time[11:13]
    minute = time[14:16]
    second = time[17:19]
    time_filename = year + '_' + month + '_' + day + '_' + hour + '_' + minute + '_' + second
    return time_filename

# %%
class BinarizeHadamardFunction(torch.autograd.Function):
    @staticmethod
    def forward(ctx, input, weight):
        ctx.save_for_backward(input, weight)
        tmp_zero = torch.zeros(weight.shape).to(weight.device)
        tmp_one = torch.ones(weight.shape).to(weight.device)
        weight_b = torch.where(weight>0, tmp_one, tmp_zero)
        output = input * weight_b
        return output

    @staticmethod
    def backward(ctx, grad_output):
        input, weight = ctx.saved_tensors
        tmp_zero = torch.zeros(weight.shape).to(weight.device)
        tmp_one = torch.ones(weight.shape).to(weight.device)
        weight_b = torch.where(weight>0, tmp_one, tmp_zero)
        grad_input = grad_weight = None
        if ctx.needs_input_grad[0]:
            grad_input = grad_output * weight_b
        if ctx.needs_input_grad[1]:
            grad_weight = grad_output * input
        return grad_input, grad_weight

class LearnableMask(nn.Module):
    def __init__(self, t=16, s=8):
        super().__init__()
        self.t = t
        self.s = s
        self.weight = nn.Parameter(torch.Tensor(t, s, s))
        self.reset_parameters()

    def reset_parameters(self):
        self.stdv = torch.sqrt(torch.tensor(1.5 / (self.s * self.s * self.t)))
        self.weight.data.uniform_(-self.stdv, self.stdv)

    def forward(self, input):
        return BinarizeHadamardFunction.apply(input, self.weight)

    def get_binary_mask(self):
        with torch.no_grad():
            return torch.where(self.weight > 0, 
                             torch.ones_like(self.weight), 
                             torch.zeros_like(self.weight))

# %%
import torch
import torch.nn as nn

#再構成モデル　DMM
class ADMM_net(nn.Module):

    def __init__(self, t=16, s=8):
        super(ADMM_net, self).__init__()
        self.mask = LearnableMask(t=t, s=s)
        self.unet1 = Unet(16, 16)
        self.unet2 = Unet(16, 16)
        self.unet3 = Unet(16, 16)
        self.unet4 = Unet(16, 16)
        self.unet5 = Unet(16, 16)
        self.gamma1 = torch.nn.Parameter(torch.Tensor([0]))
        self.gamma2 = torch.nn.Parameter(torch.Tensor([0]))
        self.gamma3 = torch.nn.Parameter(torch.Tensor([0]))
        self.gamma4 = torch.nn.Parameter(torch.Tensor([0]))
        self.gamma5 = torch.nn.Parameter(torch.Tensor([0]))

    def forward(self, x):
        # Generate measurement using learnable mask
        maskt = self.mask(x)
        y = torch.sum(maskt, dim=1)
        
        # Get binary mask for reconstruction
        binary_mask = self.mask.get_binary_mask()
        Phi = binary_mask.expand([x.shape[0], 16, 8, 8])
        Phi_s = torch.sum(binary_mask, dim=0).expand([x.shape[0], 8, 8])

        # ADMM reconstruction
        x_list = []
        theta = self.At(y, Phi)
        b = torch.zeros_like(Phi)

        # 9 stages of reconstruction
        x_list = []
        theta = self.At(y,Phi)
        b = torch.zeros_like(Phi)
        ### 1-3
        yb = self.A(theta+b,Phi)
        x = theta+b + self.At(torch.div(y-yb,Phi_s+self.gamma1),Phi)
        x1 = x-b
        theta = self.unet1(x1)
        b = b- (x-theta)
        x_list.append(theta)
        yb = self.A(theta+b,Phi)
        x = theta+b + self.At(torch.div(y-yb,Phi_s+self.gamma2),Phi)
        x1 = x-b
        theta = self.unet2(x1)
        b = b- (x-theta)
        x_list.append(theta)
        yb = self.A(theta+b,Phi)
        x = theta+b + self.At(torch.div(y-yb,Phi_s+self.gamma3),Phi)
        x1 = x-b
        theta = self.unet3(x1)
        b = b- (x-theta)
        x_list.append(theta)
        ### 4-6
        yb = self.A(theta+b,Phi)
        x = theta+b + self.At(torch.div(y-yb,Phi_s+self.gamma4),Phi)
        x1 = x-b
        theta = self.unet4(x1)
        b = b- (x-theta)
        x_list.append(theta)
        yb = self.A(theta+b,Phi)
        x = theta+b + self.At(torch.div(y-yb,Phi_s+self.gamma5),Phi)
        x1 = x-b
        theta = self.unet5(x1)
        b = b- (x-theta)
        x_list.append(theta)
        

        return x_list
    
    def A(self, x,Phi):
        temp = x*Phi
        y = torch.sum(temp,1)
        return y

    def At(self, y,Phi):

        temp = torch.unsqueeze(y, 1).repeat(1,Phi.shape[1], 1,1)
        x = temp*Phi
        return x

# %%
# maskがbayer_randomで固定バージョン(RGB画像版と対照)
from torch.utils.data import DataLoader
import torch.optim as optim
import torch.nn as nn
import torch
import scipy.io as scio
import time
import datetime
import os
import numpy as np
from torch.autograd import Variable
import matplotlib.pyplot as plt
import json

os.environ["CUDA_VISIBLE_DEVICES"] = "1"

if not torch.cuda.is_available():
    raise Exception('NO GPU!')

data_path = r"./data/"

test_path1 = r"./data/ktestdata2_gray_8x8"
#test_path1 = r"./data/test_gray"
val_path1 = r"./data/valdata_gray_8x8"
result_path1 = r"./result/ADMM_gray"
mask_path = r"./mask_8x8"

#mask_name = 'bayer_random256x256'  #完全ランダムパターン
# mask_name = 'bayer_hitomirandom256x256'  #hitomiの制約ありパターン
# mask_name = 'bayer_hamaphotorandom256x256'  #ハマホトカメラ用制約ありパターン
#mask_name ='allOne_gray'
#mask, mask_s = generate_masks(mask_path,mask_name)

last_train = 0
model_save_filename = ''
max_iter = 200
batch_size = 4
learning_rate = 0.0016
stage_num = 9
mode = 'train'  # train or test

dataset = Imgdataset(data_path)
train_data_loader = DataLoader(dataset=dataset, batch_size=batch_size, shuffle=True)

criterion = nn.MSELoss()

#if last_train != 0:
#    network = torch.load(
#        './model/' + 'monochrome/' + model_save_filename + "/model_epoch_{}.pth".format(last_train))

def compute_smoothness(tensor):
    diff_h = torch.abs(tensor[:, :, 1:] - tensor[:, :, :-1])
    diff_w = torch.abs(tensor[:, 1:, :] - tensor[:, :-1, :])
    
    # パディングして元のサイズに戻す
    diff_h = torch.nn.functional.pad(diff_h, (0, 1, 0, 0))
    diff_w = torch.nn.functional.pad(diff_w, (0, 0, 0, 1))
    
    return torch.mean(diff_h + diff_w)

def test(network, test_path, epoch, recon_path, psnr_epoch, psnr):
    network.eval()
    test_list = os.listdir(test_path)
    psnr_sample = torch.zeros(len(test_list))
    pred = []
    #compression_rate_checked = False
    
    for i in range(len(test_list)):
        pic = scio.loadmat(test_path + '/' + test_list[i])

        if "patch" in pic:
            pic = pic['patch']
#         pic = pic / 255
        elif "y" in pic:
            pic = pic['y']
        elif "p1" in pic:
            pic = pic['p1']
        elif "p2" in pic:
            pic = pic['p2']
        elif "p3" in pic:
            pic = pic['p3']
        #print(pic)
        #pic = np.transpose(pic, [2,0,1])
        pic0 = torch.from_numpy(pic).cuda().float()
        pic0 = pic0.unsqueeze(0)
        
        with torch.no_grad():
            out_pic_list = network(pic0)
            #print('y.shape:{}'.format(y.shape))
            #print('Phi.shape:{}'.format(Phi.shape))
            #print('Phi_s.shape:{}'.format(Phi_s.shape))
            out_pic = out_pic_list[-1]
            
            #print('out_pic:{}'.format(out_pic.shape))


            psnr_1 = 10 * torch.log10(1 / criterion(out_pic, pic0))

            psnr_sample[i] = psnr_1
            
            if test_path == test_path1:
                psnr[test_list[i]] = float(psnr_1)
        
        pred.append(out_pic.cpu().numpy())
        
    psnr_epoch.append(psnr_sample)
    
    if test_path == test_path1:
        psnr['test_avg'] = float(torch.mean(psnr_sample))
    else:
        psnr['val_avg'] = float(torch.mean(psnr_sample))
    
    return pred, psnr_epoch




def train_with_explicit_mask_optimization(network, train_loader, epoch, mask_lr, recon_lr, device):
    criterion = nn.MSELoss()
    
    # マスク用の最適化器と再構成ネットワーク用の最適化器を分離
    mask_optimizer = optim.Adam([
        {'params': network.mask.parameters(), 'lr': mask_lr}
    ])
    
    recon_optimizer = optim.Adam([
        {'params': network.unet1.parameters()},
        {'params': network.unet2.parameters()},
        {'params': network.unet3.parameters()},
        {'params': network.unet4.parameters()},
        {'params': network.unet5.parameters()},
        {'params': network.gamma1},
        {'params': network.gamma2},
        {'params': network.gamma3},
        {'params': network.gamma4},
        {'params': network.gamma5}
    ], lr=recon_lr)
    
    network.train()
    epoch_loss = 0
    start_time = time.time()
    
    
    for batch_idx, gt in enumerate(train_loader):
        gt = gt.to(device).float()
        
        # マスクの最適化ステップ
        #mask_optimizer.zero_grad()
        recon_optimizer.zero_grad()
        
        outputs = network(gt)
        
        # 再構成誤差
        recon_loss = (torch.sqrt(criterion(outputs[-1], gt)) + 
                    0.5 * torch.sqrt(criterion(outputs[-2], gt)) + 
                    0.5 * torch.sqrt(criterion(outputs[-3], gt)))
        
        # マスクに関する正則化項（オプション）
        #mask_sparsity = 0.01 * torch.mean(torch.abs(network.mask.weight))
        #mask_smoothness = 0.01 * compute_smoothness(network.mask.weight)
        
        # 総損失
        total_loss = recon_loss  #+ mask_sparsity + mask_smoothness
        
        total_loss.backward()
        
        # マスクと再構成ネットワークの更新を分離
        #mask_optimizer.step()
        recon_optimizer.step()
        
        epoch_loss += total_loss.item()
        
        # マスクの制約を適用（オプション）
        # with torch.no_grad():
        #     # マスクの値を0-1の範囲に制限
        #     network.mask.weight.data.clamp_(-1, 1)
            
        #     # 特定の制約条件を適用（例：各時間ステップでの露光時間の合計を制限）
        #     total_exposure = torch.sum(network.mask.get_binary_mask(), dim=(1,2))
        #     if torch.any(total_exposure > 128):  # 例：最大露光時間を128に制限
        #         scale_factor = 128 / total_exposure
        #         network.mask.weight.data *= scale_factor.view(-1, 1, 1)
    avg_epoch_loss = epoch_loss / len(train_loader)
    time_taken = time.time() - start_time
    print("====================================")
    print(f"Epoch {epoch}")
    print(f"Loss: {avg_epoch_loss:.6f}")
    print(f"Time: {time_taken:.2f}s")

    return avg_epoch_loss, time_taken, network.mask.get_binary_mask()
    

def checkpoint(network, epoch, model_path):
    model_out_path = './' + model_path + "/pre-train_epoch_{}.pth".format(epoch)
    torch.save(network, model_out_path)
    print("Checkpoint saved to {}".format(model_out_path))
    
def savemask(network, epoch, binary_mask, datetime):
    exposure_sum = torch.sum(binary_mask, dim=(1,2))
    print(f"Average exposure per frame: {exposure_sum.mean().item():.2f}")
        
    # マスクを保存
    mask_path = f'./mask_pre-train/{datetime}'
    if not os.path.exists(mask_path):
        os.makedirs(mask_path)
    scio.savemat(mask_path + f"/mask_epoch_{epoch}.mat", {
        'mask': binary_mask.cpu().numpy(),
        'raw_weights': network.mask.weight.detach().cpu().numpy()
    }) 
    



def main(mask_lr, recon_lr, mask_name):
    date_time = str(datetime.datetime.now())
    date_time = time2file_name(date_time)
    recon_path = 'recon' + '/' + 'monochrome' + '/' + mask_name + '/' + date_time
    model_path = 'model' + '/' + 'monochrome' + '/' + mask_name + '/' + date_time
    result_path = result_path1 + '/' + mask_name + '/' + date_time
    
    
    
    psnr_epoch = []
    val_psnr_epoch = []
    result_dict = []
    
    mask = mask = scio.loadmat('./mask_8x8/bayer_'+ mask_name + '.mat')
    mask = mask['mask']
    #mask = np.transpose(mask, [2, 0, 1])  # (T, H, W)の形式に変換
    mask = torch.from_numpy(mask).float()
    
    network = ADMM_net().cuda()
    #network = torch.load('./model/monochrome/2024_10_23_17_21_26_bayer_random256x256/S9_model_epoch_200.pth', map_location=torch.device('cpu'))
    # video_path = "./data/ktestdata2_gray/gray_3_aerobatics00000_3.mat"
    # model_path = "./model/monochrome/2024_10_23_17_21_26_bayer_random256x256/S9_model_epoch_200.pth"
    
    network.mask.weight.data.copy_(mask)
        
    # 再構成部分のパラメータのみ更新可能に
    # マスクのパラメータを凍結
    network.mask.requires_grad_(False)
    # 再構成部分のパラメータを更新可能に
    network.unet1.requires_grad_(True)
    network.unet2.requires_grad_(True)
    network.unet3.requires_grad_(True)
    network.unet4.requires_grad_(True)
    network.unet5.requires_grad_(True)
    network.gamma1.requires_grad_(True)
    network.gamma2.requires_grad_(True)
    network.gamma3.requires_grad_(True)
    network.gamma4.requires_grad_(True)
    network.gamma5.requires_grad_(True)

    
    for epoch in range(last_train + 1, last_train + max_iter + 1):
        psnr = {}
        
        loss, time, binary_mask = train_with_explicit_mask_optimization(network, train_data_loader, epoch, mask_lr, recon_lr, device='cuda')
        
        pred, psnr_epoch = test(network, test_path1, epoch, recon_path, psnr_epoch, psnr)
        psnr_mean = torch.mean(psnr_epoch[-1])
        
        val_pred, val_psnr_epoch = test(network, val_path1, epoch, recon_path, val_psnr_epoch, psnr)
        val_psnr_mean = torch.mean(val_psnr_epoch[-1])
        
        print("Test result: {:.4f}".format(psnr_mean))
        print("Validation result: {:.4f}".format(val_psnr_mean))
        
        result_dict.append({
            'epoch' : epoch,
            'lr' : recon_lr,
            'loss' : loss,
            'time' : time, 
            'psnr' : psnr
        })
        

        if (epoch % 10 == 0):
            if not os.path.exists(recon_path):
                os.makedirs(recon_path)
            if not os.path.exists(model_path):
                os.makedirs(model_path)
            if not os.path.exists(result_path):
                os.makedirs(result_path)
                
            with open(result_path + '/' + 'admm_gray_pre-train_result.json', 'w') as file:
                json.dump(result_dict, file, indent=4)
            name = recon_path + '/S{}'.format(stage_num) + '_pred_' + '{}_{:.4f}'.format(epoch, psnr_mean) + '.mat'
            scio.savemat(name, {'pred': pred})
            #savemask(network, epoch, binary_mask, date_time)
            checkpoint(network, epoch, model_path)
            
            
        
        if (epoch % 6 == 0) and (epoch < 300):
            mask_lr = mask_lr*0.95
            recon_lr = recon_lr*0.95
    

if __name__ == '__main__':
    mask_name_list = [
        "hitomirandom256x256_8x8",
        "hitomirandom256x256_rl_8x8",
        "hitomirandom256x256_ud_8x8",
        "hitomirandom256x256_udrl_8x8",
        "hamaphotorandom256x256_8x8",
        "hamaphotorandom256x256_rl_8x8",
        "hamaphotorandom256x256_ud_8x8",
        "hamaphotorandom256x256_udrl_8x8",
        "random256x256_8x8",
        "random256x256_rl_8x8",
        "random256x256_ud_8x8",
        "random256x256_udrl_8x8"
    ]
    for mask_name in mask_name_list:
        main(0.0001, 0.0015, mask_name)
# Out:
# ====================================
# Epoch 1
# Loss: 0.208355
# Time: 46.21s
# Test result: 22.8559
# Validation result: 23.4691
# ====================================
# Epoch 2
# Loss: 0.176458
# Time: 46.55s
# Test result: 23.3916
# Validation result: 24.1702
# ====================================
# Epoch 3
# Loss: 0.170137
# Time: 45.93s
# Test result: 23.6991
# Validation result: 24.5057
# ====================================
# Epoch 4
# Loss: 0.166955
# Time: 46.84s
# Test result: 23.4808
# Validation result: 24.2803
# ====================================
# Epoch 5
# Loss: 0.165237
# Time: 45.42s
# Test result: 23.6670
# Validation result: 24.4245
# ====================================
# Epoch 6
# Loss: 0.163885
# Time: 48.55s
# Test result: 24.1504
# Validation result: 24.6974
# ====================================
# Epoch 7
# Loss: 0.162271
# Time: 48.02s
# Test result: 24.3150
# Validation result: 25.0378
# ====================================
# Epoch 8
# Loss: 0.161500
# Time: 46.95s
# Test result: 24.0374
# Validation result: 24.7438
# ====================================
# Epoch 9
# Loss: 0.160999
# Time: 45.76s
# Test result: 24.2495
# Validation result: 25.0976
# ====================================
# Epoch 10
# Loss: 0.160276
# Time: 46.44s
# Test result: 24.1486
# Validation result: 25.0054
# Checkpoint saved to ./model/monochrome/hitomirandom256x256_8x8/2024_12_07_12_55_39/pre-train_epoch_10.pth
# ====================================
# Epoch 11
# Loss: 0.159986
# Time: 48.26s
# Test result: 24.1871
# Validation result: 25.0815
# ====================================
# Epoch 12
# Loss: 0.159558
# Time: 46.88s
# Test result: 24.3525
# Validation result: 25.3257
# ====================================
# Epoch 13
# Loss: 0.158752
# Time: 47.85s
# Test result: 24.5291
# Validation result: 25.1867
# ====================================
# Epoch 14
# Loss: 0.158469
# Time: 46.54s
# Test result: 24.3519
# Validation result: 24.9356
# ====================================
# Epoch 15
# Loss: 0.158208
# Time: 46.44s
# Test result: 24.2666
# Validation result: 25.0722
# ====================================
# Epoch 16
# Loss: 0.157973
# Time: 46.22s
# Test result: 24.1724
# Validation result: 24.9220
# ====================================
# Epoch 17
# Loss: 0.157827
# Time: 46.73s
# Test result: 24.2176
# Validation result: 24.9694
# ====================================
# Epoch 18
# Loss: 0.157729
# Time: 47.76s
# Test result: 24.3632
# Validation result: 25.0019
# ====================================
# Epoch 19
# Loss: 0.156936
# Time: 46.89s
# Test result: 24.3394
# Validation result: 25.1557
# ====================================
# Epoch 20
# Loss: 0.156989
# Time: 47.92s
# Test result: 24.4415
# Validation result: 25.1821
# Checkpoint saved to ./model/monochrome/hitomirandom256x256_8x8/2024_12_07_12_55_39/pre-train_epoch_20.pth
# ====================================
# Epoch 21
# Loss: 0.156737
# Time: 46.92s
# Test result: 24.5111
# Validation result: 25.3410
# ====================================
# Epoch 22
# Loss: 0.156499
# Time: 47.12s
# Test result: 24.4248
# Validation result: 25.2067
# ====================================
# Epoch 23
# Loss: 0.156425
# Time: 48.02s
# Test result: 24.3897
# Validation result: 25.3820
# ====================================
# Epoch 24
# Loss: 0.156391
# Time: 43.83s
# Test result: 24.3889
# Validation result: 25.2218
# ====================================
# Epoch 25
# Loss: 0.155915
# Time: 45.15s
# Test result: 24.6730
# Validation result: 25.5137
# ====================================
# Epoch 26
# Loss: 0.155727
# Time: 46.02s
# Test result: 24.4482
# Validation result: 25.3205
# ====================================
# Epoch 27
# Loss: 0.155579
# Time: 46.54s
# Test result: 24.3139
# Validation result: 25.0887
# ====================================
# Epoch 28
# Loss: 0.155607
# Time: 46.76s
# Test result: 24.5732
# Validation result: 25.4551
# ====================================
# Epoch 29
# Loss: 0.155509
# Time: 45.06s
# Test result: 24.4510
# Validation result: 25.3082
# ====================================
# Epoch 30
# Loss: 0.155427
# Time: 47.13s
# Test result: 24.5331
# Validation result: 25.5554
# Checkpoint saved to ./model/monochrome/hitomirandom256x256_8x8/2024_12_07_12_55_39/pre-train_epoch_30.pth
# ====================================
# Epoch 31
# Loss: 0.154811
# Time: 46.09s
# Test result: 24.3704
# Validation result: 25.2883
# ====================================
# Epoch 32
# Loss: 0.154889
# Time: 47.74s
# Test result: 24.7141
# Validation result: 25.6535
# ====================================
# Epoch 33
# Loss: 0.154793
# Time: 46.02s
# Test result: 24.4790
# Validation result: 25.0538
# ====================================
# Epoch 34
# Loss: 0.154500
# Time: 46.65s
# Test result: 24.4506
# Validation result: 25.3688
# ====================================
# Epoch 35
# Loss: 0.154550
# Time: 47.74s
# Test result: 24.5879
# Validation result: 25.6840
# ====================================
# Epoch 36
# Loss: 0.154420
# Time: 46.53s
# Test result: 24.7861
# Validation result: 25.6226
# ====================================
# Epoch 37
# Loss: 0.153931
# Time: 47.11s
# Test result: 24.7717
# Validation result: 25.7894
# ====================================
# Epoch 38
# Loss: 0.153891
# Time: 45.88s
# Test result: 24.5706
# Validation result: 25.1637
# ====================================
# Epoch 39
# Loss: 0.153826
# Time: 46.44s
# Test result: 24.6787
# Validation result: 25.5938
# ====================================
# Epoch 40
# Loss: 0.153818
# Time: 47.18s
# Test result: 24.5887
# Validation result: 25.5213
# Checkpoint saved to ./model/monochrome/hitomirandom256x256_8x8/2024_12_07_12_55_39/pre-train_epoch_40.pth
# ====================================
# Epoch 41
# Loss: 0.153792
# Time: 47.81s
# Test result: 24.4369
# Validation result: 25.3249
# ====================================
# Epoch 42
# Loss: 0.153800
# Time: 47.68s
# Test result: 24.4480
# Validation result: 25.2558
# ====================================
# Epoch 43
# Loss: 0.153193
# Time: 48.12s
# Test result: 24.5620
# Validation result: 25.5386
# ====================================
# Epoch 44
# Loss: 0.153115
# Time: 48.46s
# Test result: 24.6920
# Validation result: 25.3975
# ====================================
# Epoch 45
# Loss: 0.152909
# Time: 48.18s
# Test result: 24.6269
# Validation result: 25.7717
# ====================================
# Epoch 46
# Loss: 0.152910
# Time: 50.16s
# Test result: 24.7495
# Validation result: 25.6997
# ====================================
# Epoch 47
# Loss: 0.152961
# Time: 47.29s
# Test result: 24.7915
# Validation result: 25.8624
# ====================================
# Epoch 48
# Loss: 0.152836
# Time: 47.35s
# Test result: 24.3939
# Validation result: 25.1647
# ====================================
# Epoch 49
# Loss: 0.152478
# Time: 48.25s
# Test result: 24.5542
# Validation result: 25.6958
# ====================================
# Epoch 50
# Loss: 0.152376
# Time: 48.98s
# Test result: 24.7446
# Validation result: 25.5161
# Checkpoint saved to ./model/monochrome/hitomirandom256x256_8x8/2024_12_07_12_55_39/pre-train_epoch_50.pth
# ====================================
# Epoch 51
# Loss: 0.152239
# Time: 49.01s
# Test result: 24.4643
# Validation result: 25.4114
# ====================================
# Epoch 52
# Loss: 0.152489
# Time: 48.68s
# Test result: 24.8646
# Validation result: 25.7995
# ====================================
# Epoch 53
# Loss: 0.152180
# Time: 48.37s
# Test result: 24.0536
# Validation result: 24.9038
# ====================================
# Epoch 54
# Loss: 0.152312
# Time: 47.37s
# Test result: 24.7360
# Validation result: 25.7036
# ====================================
# Epoch 55
# Loss: 0.151783
# Time: 46.53s
# Test result: 24.9003
# Validation result: 25.9757
# ====================================
# Epoch 56
# Loss: 0.151727
# Time: 47.13s
# Test result: 24.7127
# Validation result: 25.8005
# ====================================
# Epoch 57
# Loss: 0.151603
# Time: 46.87s
# Test result: 25.0213
# Validation result: 25.9298
# ====================================
# Epoch 58
# Loss: 0.151635
# Time: 47.00s
# Test result: 24.5763
# Validation result: 25.5016
# ====================================
# Epoch 59
# Loss: 0.151494
# Time: 47.05s
# Test result: 24.8744
# Validation result: 25.7898
# ====================================
# Epoch 60
# Loss: 0.151655
# Time: 47.15s
# Test result: 24.8765
# Validation result: 25.8560
# Checkpoint saved to ./model/monochrome/hitomirandom256x256_8x8/2024_12_07_12_55_39/pre-train_epoch_60.pth
# ====================================
# Epoch 61
# Loss: 0.151201
# Time: 46.89s
# Test result: 24.8763
# Validation result: 25.8383
# ====================================
# Epoch 62
# Loss: 0.151062
# Time: 46.79s
# Test result: 24.6795
# Validation result: 25.5309
# ====================================
# Epoch 63
# Loss: 0.151215
# Time: 46.42s
# Test result: 24.8208
# Validation result: 25.7556
# ====================================
# Epoch 64
# Loss: 0.151083
# Time: 46.91s
# Test result: 24.7906
# Validation result: 25.7759
# ====================================
# Epoch 65
# Loss: 0.150825
# Time: 47.07s
# Test result: 24.6515
# Validation result: 25.8063
# ====================================
# Epoch 66
# Loss: 0.151095
# Time: 45.79s
# Test result: 24.8587
# Validation result: 25.6296
# ====================================
# Epoch 67
# Loss: 0.150721
# Time: 47.20s
# Test result: 24.7610
# Validation result: 25.7685
# ====================================
# Epoch 68
# Loss: 0.150520
# Time: 47.11s
# Test result: 24.7461
# Validation result: 25.5288
# ====================================
# Epoch 69
# Loss: 0.150561
# Time: 47.17s
# Test result: 24.8190
# Validation result: 25.7421
# ====================================
# Epoch 70
# Loss: 0.150523
# Time: 46.70s
# Test result: 24.8655
# Validation result: 25.7844
# Checkpoint saved to ./model/monochrome/hitomirandom256x256_8x8/2024_12_07_12_55_39/pre-train_epoch_70.pth
# ====================================
# Epoch 71
# Loss: 0.150355
# Time: 46.35s
# Test result: 24.9250
# Validation result: 25.6926
# ====================================
# Epoch 72
# Loss: 0.150579
# Time: 47.13s
# Test result: 24.6377
# Validation result: 25.4409
# ====================================
# Epoch 73
# Loss: 0.150027
# Time: 46.94s
# Test result: 24.9744
# Validation result: 25.9638
# ====================================
# Epoch 74
# Loss: 0.149887
# Time: 47.25s
# Test result: 24.5305
# Validation result: 25.4686
# ====================================
# Epoch 75
# Loss: 0.149952
# Time: 46.83s
# Test result: 24.7574
# Validation result: 25.8171
# ====================================
# Epoch 76
# Loss: 0.149922
# Time: 46.77s
# Test result: 24.6654
# Validation result: 25.6632
# ====================================
# Epoch 77
# Loss: 0.149729
# Time: 46.57s
# Test result: 24.7630
# Validation result: 25.7638
# ====================================
# Epoch 78
# Loss: 0.149877
# Time: 46.81s
# Test result: 25.0910
# Validation result: 26.0336
# ====================================
# Epoch 79
# Loss: 0.149587
# Time: 46.71s
# Test result: 24.8897
# Validation result: 25.8310
# ====================================
# Epoch 80
# Loss: 0.149427
# Time: 46.77s
# Test result: 24.8750
# Validation result: 25.8951
# Checkpoint saved to ./model/monochrome/hitomirandom256x256_8x8/2024_12_07_12_55_39/pre-train_epoch_80.pth
# ====================================
# Epoch 81
# Loss: 0.149418
# Time: 46.83s
# Test result: 25.0301
# Validation result: 25.8270
# ====================================
# Epoch 82
# Loss: 0.149466
# Time: 47.29s
# Test result: 24.9874
# Validation result: 25.8141
# ====================================
# Epoch 83
# Loss: 0.149238
# Time: 45.82s
# Test result: 24.9527
# Validation result: 25.9082
# ====================================
# Epoch 84
# Loss: 0.149222
# Time: 47.04s
# Test result: 24.9024
# Validation result: 25.8630
# ====================================
# Epoch 85
# Loss: 0.148942
# Time: 47.05s
# Test result: 24.9809
# Validation result: 25.9722
# ====================================
# Epoch 86
# Loss: 0.148788
# Time: 47.09s
# Test result: 24.7587
# Validation result: 25.7218
# ====================================
# Epoch 87
# Loss: 0.148947
# Time: 46.92s
# Test result: 24.8032
# Validation result: 26.0066
# ====================================
# Epoch 88
# Loss: 0.148699
# Time: 47.04s
# Test result: 25.0660
# Validation result: 26.1003
# ====================================
# Epoch 89
# Loss: 0.148828
# Time: 47.00s
# Test result: 24.8822
# Validation result: 25.9585
# ====================================
# Epoch 90
# Loss: 0.148782
# Time: 47.16s
# Test result: 24.8730
# Validation result: 25.8844
# Checkpoint saved to ./model/monochrome/hitomirandom256x256_8x8/2024_12_07_12_55_39/pre-train_epoch_90.pth
# ====================================
# Epoch 91
# Loss: 0.148442
# Time: 46.80s
# Test result: 25.0270
# Validation result: 26.1620
# ====================================
# Epoch 92
# Loss: 0.148564
# Time: 47.35s
# Test result: 24.9529
# Validation result: 25.7452
# ====================================
# Epoch 93
# Loss: 0.148468
# Time: 46.96s
# Test result: 24.9369
# Validation result: 25.8519
# ====================================
# Epoch 94
# Loss: 0.148440
# Time: 46.34s
# Test result: 24.8920
# Validation result: 25.9755
# ====================================
# Epoch 95
# Loss: 0.148353
# Time: 46.46s
# Test result: 24.9670
# Validation result: 26.1069
# ====================================
# Epoch 96
# Loss: 0.148299
# Time: 45.62s
# Test result: 24.8761
# Validation result: 25.8618
# ====================================
# Epoch 97
# Loss: 0.148078
# Time: 46.39s
# Test result: 25.0774
# Validation result: 26.2230
# ====================================
# Epoch 98
# Loss: 0.147825
# Time: 46.38s
# Test result: 24.9121
# Validation result: 25.7070
# ====================================
# Epoch 99
# Loss: 0.147885
# Time: 46.72s
# Test result: 25.2115
# Validation result: 26.3270
# ====================================
# Epoch 100
# Loss: 0.148011
# Time: 46.69s
# Test result: 25.0015
# Validation result: 25.8513
# Checkpoint saved to ./model/monochrome/hitomirandom256x256_8x8/2024_12_07_12_55_39/pre-train_epoch_100.pth
# ====================================
# Epoch 101
# Loss: 0.147894
# Time: 46.61s
# Test result: 25.0465
# Validation result: 26.1961
# ====================================
# Epoch 102
# Loss: 0.147699
# Time: 43.50s
# Test result: 24.9783
# Validation result: 26.0689
# ====================================
# Epoch 103
# Loss: 0.147540
# Time: 46.44s
# Test result: 25.1986
# Validation result: 26.0134
# ====================================
# Epoch 104
# Loss: 0.147547
# Time: 46.52s
# Test result: 25.0595
# Validation result: 25.9307
# ====================================
# Epoch 105
# Loss: 0.147392
# Time: 46.42s
# Test result: 24.9196
# Validation result: 26.0867
# ====================================
# Epoch 106
# Loss: 0.147338
# Time: 46.34s
# Test result: 25.1716
# Validation result: 26.1307
# ====================================
# Epoch 107
# Loss: 0.147431
# Time: 46.36s
# Test result: 24.8895
# Validation result: 25.8485
# ====================================
# Epoch 108
# Loss: 0.147314
# Time: 46.63s
# Test result: 24.9931
# Validation result: 25.9934
# ====================================
# Epoch 109
# Loss: 0.146935
# Time: 45.27s
# Test result: 25.2330
# Validation result: 26.0238
# ====================================
# Epoch 110
# Loss: 0.146992
# Time: 47.25s
# Test result: 25.1227
# Validation result: 26.3357
# Checkpoint saved to ./model/monochrome/hitomirandom256x256_8x8/2024_12_07_12_55_39/pre-train_epoch_110.pth
# ====================================
# Epoch 111
# Loss: 0.146969
# Time: 47.08s
# Test result: 25.1717
# Validation result: 26.1827
# ====================================
# Epoch 112
# Loss: 0.146985
# Time: 47.03s
# Test result: 25.0716
# Validation result: 26.0885
# ====================================
# Epoch 113
# Loss: 0.146887
# Time: 46.24s
# Test result: 25.0094
# Validation result: 26.0058
# ====================================
# Epoch 114
# Loss: 0.146946
# Time: 42.90s
# Test result: 25.1615
# Validation result: 26.3284
# ====================================
# Epoch 115
# Loss: 0.146695
# Time: 44.40s
# Test result: 25.1172
# Validation result: 26.0629
# ====================================
# Epoch 116
# Loss: 0.146495
# Time: 46.36s
# Test result: 25.1788
# Validation result: 26.0216
# ====================================
# Epoch 117
# Loss: 0.146568
# Time: 46.63s
# Test result: 25.0652
# Validation result: 26.0449
# ====================================
# Epoch 118
# Loss: 0.146709
# Time: 46.80s
# Test result: 24.9286
# Validation result: 25.8896
# ====================================
# Epoch 119
# Loss: 0.146600
# Time: 46.70s
# Test result: 24.9485
# Validation result: 26.0851
# ====================================
# Epoch 120
# Loss: 0.146454
# Time: 46.83s
# Test result: 24.9852
# Validation result: 25.9843
# Checkpoint saved to ./model/monochrome/hitomirandom256x256_8x8/2024_12_07_12_55_39/pre-train_epoch_120.pth
# ====================================
# Epoch 121
# Loss: 0.146279
# Time: 47.11s
# Test result: 25.2571
# Validation result: 26.0982
# ====================================
# Epoch 122
# Loss: 0.146120
# Time: 46.99s
# Test result: 25.1744
# Validation result: 26.2939
# ====================================
# Epoch 123
# Loss: 0.146103
# Time: 44.87s
# Test result: 25.1992
# Validation result: 26.2421
# ====================================
# Epoch 124
# Loss: 0.146063
# Time: 43.81s
# Test result: 25.1324
# Validation result: 26.2318
# ====================================
# Epoch 125
# Loss: 0.145973
# Time: 46.61s
# Test result: 25.2124
# Validation result: 26.3254
# ====================================
# Epoch 126
# Loss: 0.146054
# Time: 45.65s
# Test result: 24.8334
# Validation result: 25.7364
# ====================================
# Epoch 127
# Loss: 0.145691
# Time: 47.21s
# Test result: 25.1151
# Validation result: 26.1626
# ====================================
# Epoch 128
# Loss: 0.145829
# Time: 47.09s
# Test result: 25.0660
# Validation result: 26.3500
# ====================================
# Epoch 129
# Loss: 0.145764
# Time: 47.03s
# Test result: 25.2143
# Validation result: 26.3671
# ====================================
# Epoch 130
# Loss: 0.145699
# Time: 46.41s
# Test result: 25.1147
# Validation result: 26.1980
# Checkpoint saved to ./model/monochrome/hitomirandom256x256_8x8/2024_12_07_12_55_39/pre-train_epoch_130.pth
# ====================================
# Epoch 131
# Loss: 0.145489
# Time: 42.40s
# Test result: 25.2862
# Validation result: 26.3828
# ====================================
# Epoch 132
# Loss: 0.145721
# Time: 46.65s
# Test result: 25.1376
# Validation result: 26.3685
# ====================================
# Epoch 133
# Loss: 0.145423
# Time: 46.97s
# Test result: 25.1580
# Validation result: 26.2206
# ====================================
# Epoch 134
# Loss: 0.145294
# Time: 46.85s
# Test result: 25.2248
# Validation result: 26.4032
# ====================================
# Epoch 135
# Loss: 0.145323
# Time: 46.73s
# Test result: 24.8227
# Validation result: 26.2970
# ====================================
# Epoch 136
# Loss: 0.145190
# Time: 46.94s
# Test result: 25.2066
# Validation result: 26.2664
# ====================================
# Epoch 137
# Loss: 0.145297
# Time: 47.05s
# Test result: 25.2832
# Validation result: 26.3988
# ====================================
# Epoch 138
# Loss: 0.145271
# Time: 46.72s
# Test result: 25.1396
# Validation result: 26.3368
# ====================================
# Epoch 139
# Loss: 0.145027
# Time: 44.11s
# Test result: 24.8547
# Validation result: 25.8351
# ====================================
# Epoch 140
# Loss: 0.144933
# Time: 46.99s
# Test result: 24.8292
# Validation result: 25.9307
# Checkpoint saved to ./model/monochrome/hitomirandom256x256_8x8/2024_12_07_12_55_39/pre-train_epoch_140.pth
# ====================================
# Epoch 141
# Loss: 0.144919
# Time: 47.10s
# Test result: 24.9042
# Validation result: 25.9646
# ====================================
# Epoch 142
# Loss: 0.144801
# Time: 46.95s
# Test result: 25.2136
# Validation result: 26.3235
# ====================================
# Epoch 143
# Loss: 0.144746
# Time: 46.53s
# Test result: 25.0478
# Validation result: 26.2533
# ====================================
# Epoch 144
# Loss: 0.144782
# Time: 46.83s
# Test result: 25.2286
# Validation result: 26.2149
# ====================================
# Epoch 145
# Loss: 0.144719
# Time: 46.38s
# Test result: 25.2128
# Validation result: 26.1607
# ====================================
# Epoch 146
# Loss: 0.144604
# Time: 46.33s
# Test result: 25.2021
# Validation result: 26.3684
# ====================================
# Epoch 147
# Loss: 0.144491
# Time: 41.11s
# Test result: 25.1169
# Validation result: 26.3220
# ====================================
# Epoch 148
# Loss: 0.144441
# Time: 47.10s
# Test result: 25.1560
# Validation result: 26.3717
# ====================================
# Epoch 149
# Loss: 0.144438
# Time: 46.81s
# Test result: 24.9949
# Validation result: 26.1840
# ====================================
# Epoch 150
# Loss: 0.144364
# Time: 46.81s
# Test result: 24.9694
# Validation result: 26.1091
# Checkpoint saved to ./model/monochrome/hitomirandom256x256_8x8/2024_12_07_12_55_39/pre-train_epoch_150.pth
# ====================================
# Epoch 151
# Loss: 0.144187
# Time: 45.10s
# Test result: 25.2641
# Validation result: 26.3595
# ====================================
# Epoch 152
# Loss: 0.144117
# Time: 46.29s
# Test result: 25.2202
# Validation result: 26.4169
# ====================================
# Epoch 153
# Loss: 0.143958
# Time: 46.76s
# Test result: 25.2564
# Validation result: 26.5305
# ====================================
# Epoch 154
# Loss: 0.143970
# Time: 46.50s
# Test result: 25.2038
# Validation result: 26.3467
# ====================================
# Epoch 155
# Loss: 0.144016
# Time: 46.03s
# Test result: 25.2848
# Validation result: 26.4149
# ====================================
# Epoch 156
# Loss: 0.144103
# Time: 46.58s
# Test result: 25.3252
# Validation result: 26.5479
# ====================================
# Epoch 157
# Loss: 0.143877
# Time: 46.80s
# Test result: 25.1540
# Validation result: 26.2650
# ====================================
# Epoch 158
# Loss: 0.143852
# Time: 46.94s
# Test result: 25.2484
# Validation result: 26.2331
# ====================================
# Epoch 159
# Loss: 0.143691
# Time: 46.57s
# Test result: 25.2047
# Validation result: 26.4276
# ====================================
# Epoch 160
# Loss: 0.143676
# Time: 46.83s
# Test result: 25.2944
# Validation result: 26.4889
# Checkpoint saved to ./model/monochrome/hitomirandom256x256_8x8/2024_12_07_12_55_39/pre-train_epoch_160.pth
# ====================================
# Epoch 161
# Loss: 0.143692
# Time: 46.92s
# Test result: 25.1896
# Validation result: 26.1577
# ====================================
# Epoch 162
# Loss: 0.143468
# Time: 46.79s
# Test result: 25.2885
# Validation result: 26.2641
# ====================================
# Epoch 163
# Loss: 0.143406
# Time: 42.74s
# Test result: 25.2556
# Validation result: 26.4764
# ====================================
# Epoch 164
# Loss: 0.143424
# Time: 46.35s
# Test result: 25.2655
# Validation result: 26.5935
# ====================================
# Epoch 165
# Loss: 0.143407
# Time: 46.15s
# Test result: 25.1536
# Validation result: 26.4800
# ====================================
# Epoch 166
# Loss: 0.143356
# Time: 45.75s
# Test result: 25.2812
# Validation result: 26.3883
# ====================================
# Epoch 167
# Loss: 0.143324
# Time: 46.18s
# Test result: 25.3177
# Validation result: 26.2929
# ====================================
# Epoch 168
# Loss: 0.143401
# Time: 44.89s
# Test result: 25.2039
# Validation result: 26.4497
# ====================================
# Epoch 169
# Loss: 0.143217
# Time: 45.47s
# Test result: 25.2685
# Validation result: 26.5059
# ====================================
# Epoch 170
# Loss: 0.143013
# Time: 44.98s
# Test result: 25.3149
# Validation result: 26.5084
# Checkpoint saved to ./model/monochrome/hitomirandom256x256_8x8/2024_12_07_12_55_39/pre-train_epoch_170.pth
# ====================================
# Epoch 171
# Loss: 0.143057
# Time: 44.24s
# Test result: 25.1118
# Validation result: 26.4701
# ====================================
# Epoch 172
# Loss: 0.143098
# Time: 46.76s
# Test result: 25.2054
# Validation result: 26.4871
# ====================================
# Epoch 173
# Loss: 0.143054
# Time: 46.87s
# Test result: 25.1933
# Validation result: 26.4771
# ====================================
# Epoch 174
# Loss: 0.142904
# Time: 46.79s
# Test result: 25.2703
# Validation result: 26.5010
# ====================================
# Epoch 175
# Loss: 0.142681
# Time: 46.74s
# Test result: 25.0935
# Validation result: 26.4297
# ====================================
# Epoch 176
# Loss: 0.142690
# Time: 41.13s
# Test result: 25.3317
# Validation result: 26.4855
# ====================================
# Epoch 177
# Loss: 0.142753
# Time: 40.81s
# Test result: 25.1629
# Validation result: 26.5189
# ====================================
# Epoch 178
# Loss: 0.142695
# Time: 47.22s
# Test result: 25.1922
# Validation result: 26.4563
# ====================================
# Epoch 179
# Loss: 0.142555
# Time: 45.55s
# Test result: 25.3562
# Validation result: 26.6903
# ====================================
# Epoch 180
# Loss: 0.142556
# Time: 46.11s
# Test result: 25.2195
# Validation result: 26.4301
# Checkpoint saved to ./model/monochrome/hitomirandom256x256_8x8/2024_12_07_12_55_39/pre-train_epoch_180.pth
# ====================================
# Epoch 181
# Loss: 0.142413
# Time: 44.82s
# Test result: 25.2739
# Validation result: 26.5301
# ====================================
# Epoch 182
# Loss: 0.142356
# Time: 47.08s
# Test result: 25.2178
# Validation result: 26.6026
# ====================================
# Epoch 183
# Loss: 0.142503
# Time: 46.35s
# Test result: 25.2790
# Validation result: 26.6553
# ====================================
# Epoch 184
# Loss: 0.142454
# Time: 46.60s
# Test result: 25.2819
# Validation result: 26.6110
# ====================================
# Epoch 185
# Loss: 0.142428
# Time: 44.30s
# Test result: 25.2542
# Validation result: 26.4778
# ====================================
# Epoch 186
# Loss: 0.142336
# Time: 46.89s
# Test result: 25.0761
# Validation result: 26.3847
# ====================================
# Epoch 187
# Loss: 0.142052
# Time: 47.31s
# Test result: 25.0435
# Validation result: 26.3433
# ====================================
# Epoch 188
# Loss: 0.142062
# Time: 46.41s
# Test result: 25.1726
# Validation result: 26.5434
# ====================================
# Epoch 189
# Loss: 0.142129
# Time: 46.84s
# Test result: 25.2386
# Validation result: 26.4993
# ====================================
# Epoch 190
# Loss: 0.142030
# Time: 45.34s
# Test result: 25.2476
# Validation result: 26.4150
# Checkpoint saved to ./model/monochrome/hitomirandom256x256_8x8/2024_12_07_12_55_39/pre-train_epoch_190.pth
# ====================================
# Epoch 191
# Loss: 0.141982
# Time: 45.58s
# Test result: 25.2814
# Validation result: 26.4726
# ====================================
# Epoch 192
# Loss: 0.142084
# Time: 47.31s
# Test result: 25.2506
# Validation result: 26.4419
# ====================================
# Epoch 193
# Loss: 0.141802
# Time: 46.89s
# Test result: 25.2198
# Validation result: 26.5353
# ====================================
# Epoch 194
# Loss: 0.141642
# Time: 46.92s
# Test result: 25.3247
# Validation result: 26.7247
# ====================================
# Epoch 195
# Loss: 0.141723
# Time: 46.83s
# Test result: 25.2102
# Validation result: 26.5327
# ====================================
# Epoch 196
# Loss: 0.141743
# Time: 46.95s
# Test result: 25.1887
# Validation result: 26.4718
# ====================================
# Epoch 197
# Loss: 0.141714
# Time: 46.92s
# Test result: 25.3089
# Validation result: 26.5810
# ====================================
# Epoch 198
# Loss: 0.141613
# Time: 47.07s
# Test result: 25.3380
# Validation result: 26.6420
# ====================================
# Epoch 199
# Loss: 0.141501
# Time: 47.55s
# Test result: 25.1961
# Validation result: 26.3810
# ====================================
# Epoch 200
# Loss: 0.141440
# Time: 46.90s
# Test result: 25.1634
# Validation result: 26.5208
# Checkpoint saved to ./model/monochrome/hitomirandom256x256_8x8/2024_12_07_12_55_39/pre-train_epoch_200.pth
# ====================================
# Epoch 1
# Loss: 0.202169
# Time: 45.14s
# Test result: 22.8835
# Validation result: 23.2552
# ====================================
# Epoch 2
# Loss: 0.171524
# Time: 46.71s
# Test result: 23.9914
# Validation result: 24.6514
# ====================================
# Epoch 3
# Loss: 0.167122
# Time: 46.94s
# Test result: 23.5292
# Validation result: 24.0813
# ====================================
# Epoch 4
# Loss: 0.164624
# Time: 47.40s
# Test result: 24.0855
# Validation result: 24.8318
# ====================================
# Epoch 5
# Loss: 0.163017
# Time: 45.81s
# Test result: 24.2696
# Validation result: 25.1670
# ====================================
# Epoch 6
# Loss: 0.162061
# Time: 46.80s
# Test result: 24.3137
# Validation result: 24.9920
# ====================================
# Epoch 7
# Loss: 0.160830
# Time: 44.54s
# Test result: 24.1256
# Validation result: 25.0906
# ====================================
# Epoch 8
# Loss: 0.160344
# Time: 46.20s
# Test result: 24.1352
# Validation result: 25.0073
# ====================================
# Epoch 9
# Loss: 0.159809
# Time: 45.68s
# Test result: 24.2747
# Validation result: 24.8912
# ====================================
# Epoch 10
# Loss: 0.159382
# Time: 46.72s
# Test result: 24.4303
# Validation result: 25.0745
# Checkpoint saved to ./model/monochrome/hitomirandom256x256_rl_8x8/2024_12_07_15_55_00/pre-train_epoch_10.pth
# ====================================
# Epoch 11
# Loss: 0.158939
# Time: 46.48s
# Test result: 24.3768
# Validation result: 25.1488
# ====================================
# Epoch 12
# Loss: 0.158546
# Time: 46.09s
# Test result: 24.5130
# Validation result: 25.2159
# ====================================
# Epoch 13
# Loss: 0.157940
# Time: 46.76s
# Test result: 24.3641
# Validation result: 25.2442
# ====================================
# Epoch 14
# Loss: 0.157570
# Time: 46.68s
# Test result: 24.5509
# Validation result: 25.5377
# ====================================
# Epoch 15
# Loss: 0.157470
# Time: 46.75s
# Test result: 24.4358
# Validation result: 25.4232
# ====================================
# Epoch 16
# Loss: 0.157302
# Time: 46.84s
# Test result: 24.6544
# Validation result: 25.5841
# ====================================
# Epoch 17
# Loss: 0.157113
# Time: 45.68s
# Test result: 24.5761
# Validation result: 25.2321
# ====================================
# Epoch 18
# Loss: 0.156855
# Time: 47.39s
# Test result: 24.4668
# Validation result: 25.1226
# ====================================
# Epoch 19
# Loss: 0.156130
# Time: 43.93s
# Test result: 24.4354
# Validation result: 25.2975
# ====================================
# Epoch 20
# Loss: 0.156034
# Time: 43.68s
# Test result: 24.3101
# Validation result: 25.1101
# Checkpoint saved to ./model/monochrome/hitomirandom256x256_rl_8x8/2024_12_07_15_55_00/pre-train_epoch_20.pth
# ====================================
# Epoch 21
# Loss: 0.155935
# Time: 45.94s
# Test result: 24.3851
# Validation result: 25.1313
# ====================================
# Epoch 22
# Loss: 0.155842
# Time: 45.97s
# Test result: 24.5673
# Validation result: 25.6046
# ====================================
# Epoch 23
# Loss: 0.155739
# Time: 47.21s
# Test result: 24.6780
# Validation result: 25.5396
# ====================================
# Epoch 24
# Loss: 0.155763
# Time: 41.83s
# Test result: 24.7268
# Validation result: 25.5597
# ====================================
# Epoch 25
# Loss: 0.155132
# Time: 43.28s
# Test result: 24.6838
# Validation result: 25.6124
# ====================================
# Epoch 26
# Loss: 0.154939
# Time: 47.11s
# Test result: 24.5229
# Validation result: 25.1508
# ====================================
# Epoch 27
# Loss: 0.154760
# Time: 45.66s
# Test result: 24.2195
# Validation result: 25.0503
# ====================================
# Epoch 28
# Loss: 0.154556
# Time: 47.36s
# Test result: 24.6006
# Validation result: 25.2866
# ====================================
# Epoch 29
# Loss: 0.154723
# Time: 46.84s
# Test result: 24.7741
# Validation result: 25.6830
# ====================================
# Epoch 30
# Loss: 0.154918
# Time: 46.11s
# Test result: 24.5528
# Validation result: 25.4891
# Checkpoint saved to ./model/monochrome/hitomirandom256x256_rl_8x8/2024_12_07_15_55_00/pre-train_epoch_30.pth
# ====================================
# Epoch 31
# Loss: 0.154216
# Time: 46.71s
# Test result: 24.6154
# Validation result: 25.4786
# ====================================
# Epoch 32
# Loss: 0.153805
# Time: 42.02s
# Test result: 24.6218
# Validation result: 25.4106
# ====================================
# Epoch 33
# Loss: 0.154026
# Time: 45.66s
# Test result: 24.5264
# Validation result: 25.4170
# ====================================
# Epoch 34
# Loss: 0.153943
# Time: 47.16s
# Test result: 24.9166
# Validation result: 25.6292
# ====================================
# Epoch 35
# Loss: 0.153776
# Time: 47.20s
# Test result: 24.7205
# Validation result: 25.6635
# ====================================
# Epoch 36
# Loss: 0.153717
# Time: 47.33s
# Test result: 24.6014
# Validation result: 25.3656
# ====================================
# Epoch 37
# Loss: 0.153341
# Time: 46.57s
# Test result: 24.6084
# Validation result: 25.4126
# ====================================
# Epoch 38
# Loss: 0.153142
# Time: 46.82s
# Test result: 24.5789
# Validation result: 25.5602
# ====================================
# Epoch 39
# Loss: 0.153100
# Time: 47.10s
# Test result: 24.7886
# Validation result: 25.6448
# ====================================
# Epoch 40
# Loss: 0.153050
# Time: 47.07s
# Test result: 25.0100
# Validation result: 25.9552
# Checkpoint saved to ./model/monochrome/hitomirandom256x256_rl_8x8/2024_12_07_15_55_00/pre-train_epoch_40.pth
# ====================================
# Epoch 41
# Loss: 0.153038
# Time: 46.76s
# Test result: 24.4874
# Validation result: 25.3862
# ====================================
# Epoch 42
# Loss: 0.152984
# Time: 47.17s
# Test result: 25.1105
# Validation result: 26.0696
# ====================================
# Epoch 43
# Loss: 0.152519
# Time: 47.36s
# Test result: 24.7506
# Validation result: 25.6678
# ====================================
# Epoch 44
# Loss: 0.152392
# Time: 47.23s
# Test result: 24.8018
# Validation result: 25.6529
# ====================================
# Epoch 45
# Loss: 0.153232
# Time: 46.63s
# Test result: 24.5913
# Validation result: 25.5081
# ====================================
# Epoch 46
# Loss: 0.153027
# Time: 46.67s
# Test result: 24.6040
# Validation result: 25.4885
# ====================================
# Epoch 47
# Loss: 0.152802
# Time: 46.31s
# Test result: 24.9172
# Validation result: 25.7146
# ====================================
# Epoch 48
# Loss: 0.152878
# Time: 46.85s
# Test result: 24.8352
# Validation result: 25.7933
# ====================================
# Epoch 49
# Loss: 0.152330
# Time: 47.25s
# Test result: 24.5899
# Validation result: 25.3982
# ====================================
# Epoch 50
# Loss: 0.152320
# Time: 46.13s
# Test result: 24.7407
# Validation result: 25.7007
# Checkpoint saved to ./model/monochrome/hitomirandom256x256_rl_8x8/2024_12_07_15_55_00/pre-train_epoch_50.pth
# ====================================
# Epoch 51
# Loss: 0.152068
# Time: 47.02s
# Test result: 24.5092
# Validation result: 25.4778
# ====================================
# Epoch 52
# Loss: 0.152241
# Time: 46.85s
# Test result: 24.7699
# Validation result: 25.6855
# ====================================
# Epoch 53
# Loss: 0.152147
# Time: 47.07s
# Test result: 24.5583
# Validation result: 25.3589
# ====================================
# Epoch 54
# Loss: 0.151998
# Time: 45.60s
# Test result: 24.5779
# Validation result: 25.4493
# ====================================
# Epoch 55
# Loss: 0.151517
# Time: 46.68s
# Test result: 24.7215
# Validation result: 25.6941
# ====================================
# Epoch 56
# Loss: 0.151597
# Time: 47.14s
# Test result: 24.7062
# Validation result: 25.6933
# ====================================
# Epoch 57
# Loss: 0.151483
# Time: 47.20s
# Test result: 24.8949
# Validation result: 25.7679
# ====================================
# Epoch 58
# Loss: 0.151395
# Time: 46.59s
# Test result: 24.8470
# Validation result: 25.6681
# ====================================
# Epoch 59
# Loss: 0.151379
# Time: 47.26s
# Test result: 24.8329
# Validation result: 25.5472
# ====================================
# Epoch 60
# Loss: 0.151279
# Time: 47.16s
# Test result: 24.9346
# Validation result: 25.8984
# Checkpoint saved to ./model/monochrome/hitomirandom256x256_rl_8x8/2024_12_07_15_55_00/pre-train_epoch_60.pth
# ====================================
# Epoch 61
# Loss: 0.150956
# Time: 46.65s
# Test result: 25.1729
# Validation result: 26.0730
# ====================================
# Epoch 62
# Loss: 0.150737
# Time: 46.04s
# Test result: 24.9488
# Validation result: 25.7177
# ====================================
# Epoch 63
# Loss: 0.150765
# Time: 46.38s
# Test result: 24.9390
# Validation result: 25.7802
# ====================================
# Epoch 64
# Loss: 0.150863
# Time: 44.25s
# Test result: 24.9410
# Validation result: 25.8563
# ====================================
# Epoch 65
# Loss: 0.150586
# Time: 47.03s
# Test result: 25.1190
# Validation result: 26.0825
# ====================================
# Epoch 66
# Loss: 0.150550
# Time: 44.12s
# Test result: 24.8620
# Validation result: 25.8213
# ====================================
# Epoch 67
# Loss: 0.150401
# Time: 46.43s
# Test result: 24.7964
# Validation result: 25.5418
# ====================================
# Epoch 68
# Loss: 0.150327
# Time: 45.41s
# Test result: 25.1130
# Validation result: 26.1322
# ====================================
# Epoch 69
# Loss: 0.150188
# Time: 46.56s
# Test result: 25.1243
# Validation result: 26.2013
# ====================================
# Epoch 70
# Loss: 0.150189
# Time: 46.86s
# Test result: 24.9218
# Validation result: 26.1329
# Checkpoint saved to ./model/monochrome/hitomirandom256x256_rl_8x8/2024_12_07_15_55_00/pre-train_epoch_70.pth
# ====================================
# Epoch 71
# Loss: 0.150016
# Time: 46.33s
# Test result: 25.0090
# Validation result: 25.9128
# ====================================
# Epoch 72
# Loss: 0.150114
# Time: 45.55s
# Test result: 24.8959
# Validation result: 25.7895
# ====================================
# Epoch 73
# Loss: 0.149846
# Time: 45.87s
# Test result: 25.0708
# Validation result: 25.9127
# ====================================
# Epoch 74
# Loss: 0.149642
# Time: 47.45s
# Test result: 24.9521
# Validation result: 25.8144
# ====================================
# Epoch 75
# Loss: 0.149559
# Time: 46.61s
# Test result: 24.9974
# Validation result: 25.8796
# ====================================
# Epoch 76
# Loss: 0.149496
# Time: 46.86s
# Test result: 24.9552
# Validation result: 25.8549
# ====================================
# Epoch 77
# Loss: 0.149529
# Time: 46.16s
# Test result: 25.0709
# Validation result: 26.0294
# ====================================
# Epoch 78
# Loss: 0.149501
# Time: 47.05s
# Test result: 25.0688
# Validation result: 25.9553
# ====================================
# Epoch 79
# Loss: 0.149140
# Time: 45.74s
# Test result: 24.9502
# Validation result: 25.9470
# ====================================
# Epoch 80
# Loss: 0.148963
# Time: 46.61s
# Test result: 25.0567
# Validation result: 26.1587
# Checkpoint saved to ./model/monochrome/hitomirandom256x256_rl_8x8/2024_12_07_15_55_00/pre-train_epoch_80.pth
# ====================================
# Epoch 81
# Loss: 0.149031
# Time: 46.96s
# Test result: 24.9873
# Validation result: 25.7812
# ====================================
# Epoch 82
# Loss: 0.149040
# Time: 46.62s
# Test result: 24.6507
# Validation result: 25.5050
# ====================================
# Epoch 83
# Loss: 0.149123
# Time: 46.65s
# Test result: 25.2226
# Validation result: 26.0998
# ====================================
# Epoch 84
# Loss: 0.148973
# Time: 46.73s
# Test result: 25.0556
# Validation result: 26.1434
# ====================================
# Epoch 85
# Loss: 0.148691
# Time: 46.34s
# Test result: 25.1340
# Validation result: 26.2148
# ====================================
# Epoch 86
# Loss: 0.148562
# Time: 46.29s
# Test result: 25.0078
# Validation result: 26.1221
# ====================================
# Epoch 87
# Loss: 0.148532
# Time: 46.77s
# Test result: 25.0910
# Validation result: 25.9485
# ====================================
# Epoch 88
# Loss: 0.148692
# Time: 47.34s
# Test result: 25.0677
# Validation result: 25.7841
# ====================================
# Epoch 89
# Loss: 0.148433
# Time: 46.45s
# Test result: 25.0965
# Validation result: 26.2814
# ====================================
# Epoch 90
# Loss: 0.148421
# Time: 45.66s
# Test result: 25.0556
# Validation result: 25.9996
# Checkpoint saved to ./model/monochrome/hitomirandom256x256_rl_8x8/2024_12_07_15_55_00/pre-train_epoch_90.pth
# ====================================
# Epoch 91
# Loss: 0.148207
# Time: 45.75s
# Test result: 25.0974
# Validation result: 26.1228
# ====================================
# Epoch 92
# Loss: 0.148011
# Time: 46.36s
# Test result: 25.0797
# Validation result: 25.9906
# ====================================
# Epoch 93
# Loss: 0.148088
# Time: 46.74s
# Test result: 24.9542
# Validation result: 25.7385
# ====================================
# Epoch 94
# Loss: 0.147936
# Time: 46.14s
# Test result: 25.2625
# Validation result: 26.3619
# ====================================
# Epoch 95
# Loss: 0.148025
# Time: 46.72s
# Test result: 25.2679
# Validation result: 26.2033
# ====================================
# Epoch 96
# Loss: 0.147886
# Time: 46.52s
# Test result: 25.2517
# Validation result: 26.3188
# ====================================
# Epoch 97
# Loss: 0.147637
# Time: 46.73s
# Test result: 25.0341
# Validation result: 25.9747
# ====================================
# Epoch 98
# Loss: 0.147605
# Time: 46.79s
# Test result: 25.0966
# Validation result: 26.0554
# ====================================
# Epoch 99
# Loss: 0.147577
# Time: 46.72s
# Test result: 25.1820
# Validation result: 26.0707
# ====================================
# Epoch 100
# Loss: 0.147502
# Time: 47.04s
# Test result: 25.1373
# Validation result: 26.1045
# Checkpoint saved to ./model/monochrome/hitomirandom256x256_rl_8x8/2024_12_07_15_55_00/pre-train_epoch_100.pth
# ====================================
# Epoch 101
# Loss: 0.147513
# Time: 46.93s
# Test result: 25.1503
# Validation result: 26.0968
# ====================================
# Epoch 102
# Loss: 0.147611
# Time: 46.93s
# Test result: 25.1229
# Validation result: 26.0086
# ====================================
# Epoch 103
# Loss: 0.147146
# Time: 47.08s
# Test result: 25.2167
# Validation result: 26.1543
# ====================================
# Epoch 104
# Loss: 0.147063
# Time: 47.07s
# Test result: 25.2956
# Validation result: 26.3184
# ====================================
# Epoch 105
# Loss: 0.147048
# Time: 47.00s
# Test result: 25.2662
# Validation result: 26.0829
# ====================================
# Epoch 106
# Loss: 0.147077
# Time: 44.95s
# Test result: 25.2764
# Validation result: 26.3087
# ====================================
# Epoch 107
# Loss: 0.147140
# Time: 46.22s
# Test result: 25.2993
# Validation result: 26.3102
# ====================================
# Epoch 108
# Loss: 0.146961
# Time: 47.15s
# Test result: 25.2112
# Validation result: 26.2773
# ====================================
# Epoch 109
# Loss: 0.146718
# Time: 46.85s
# Test result: 25.1889
# Validation result: 26.0423
# ====================================
# Epoch 110
# Loss: 0.146728
# Time: 46.21s
# Test result: 25.3933
# Validation result: 26.3050
# Checkpoint saved to ./model/monochrome/hitomirandom256x256_rl_8x8/2024_12_07_15_55_00/pre-train_epoch_110.pth
# ====================================
# Epoch 111
# Loss: 0.146529
# Time: 44.00s
# Test result: 25.2228
# Validation result: 26.3727
# ====================================
# Epoch 112
# Loss: 0.146632
# Time: 41.47s
# Test result: 25.2523
# Validation result: 26.1761
# ====================================
# Epoch 113
# Loss: 0.146588
# Time: 44.24s
# Test result: 25.2491
# Validation result: 26.2636
# ====================================
# Epoch 114
# Loss: 0.146482
# Time: 46.33s
# Test result: 25.3061
# Validation result: 26.3802
# ====================================
# Epoch 115
# Loss: 0.146214
# Time: 46.24s
# Test result: 25.3309
# Validation result: 26.3620
# ====================================
# Epoch 116
# Loss: 0.146225
# Time: 46.36s
# Test result: 25.2615
# Validation result: 26.2540
# ====================================
# Epoch 117
# Loss: 0.146215
# Time: 46.57s
# Test result: 25.3722
# Validation result: 26.3389
# ====================================
# Epoch 118
# Loss: 0.146172
# Time: 46.44s
# Test result: 25.2800
# Validation result: 26.0548
# ====================================
# Epoch 119
# Loss: 0.146226
# Time: 46.56s
# Test result: 25.1460
# Validation result: 26.1035
# ====================================
# Epoch 120
# Loss: 0.146032
# Time: 42.79s
# Test result: 25.1589
# Validation result: 26.1494
# Checkpoint saved to ./model/monochrome/hitomirandom256x256_rl_8x8/2024_12_07_15_55_00/pre-train_epoch_120.pth
# ====================================
# Epoch 121
# Loss: 0.145957
# Time: 46.85s
# Test result: 25.3928
# Validation result: 26.2696
# ====================================
# Epoch 122
# Loss: 0.145891
# Time: 46.62s
# Test result: 25.1305
# Validation result: 26.2257
# ====================================
# Epoch 123
# Loss: 0.145730
# Time: 47.03s
# Test result: 25.3870
# Validation result: 26.3205
# ====================================
# Epoch 124
# Loss: 0.145764
# Time: 47.19s
# Test result: 25.3117
# Validation result: 26.3374
# ====================================
# Epoch 125
# Loss: 0.145662
# Time: 47.14s
# Test result: 25.3046
# Validation result: 26.2543
# ====================================
# Epoch 126
# Loss: 0.145708
# Time: 46.44s
# Test result: 25.4925
# Validation result: 26.4709
# ====================================
# Epoch 127
# Loss: 0.145413
# Time: 46.71s
# Test result: 25.1174
# Validation result: 26.1376
# ====================================
# Epoch 128
# Loss: 0.145419
# Time: 46.31s
# Test result: 25.3118
# Validation result: 26.3261
# ====================================
# Epoch 129
# Loss: 0.145424
# Time: 46.90s
# Test result: 25.3929
# Validation result: 26.3552
# ====================================
# Epoch 130
# Loss: 0.145265
# Time: 46.01s
# Test result: 25.3328
# Validation result: 26.3980
# Checkpoint saved to ./model/monochrome/hitomirandom256x256_rl_8x8/2024_12_07_15_55_00/pre-train_epoch_130.pth
# ====================================
# Epoch 131
# Loss: 0.145275
# Time: 45.85s
# Test result: 25.1345
# Validation result: 26.1536
# ====================================
# Epoch 132
# Loss: 0.145243
# Time: 46.39s
# Test result: 25.2372
# Validation result: 26.2821
# ====================================
# Epoch 133
# Loss: 0.145070
# Time: 45.97s
# Test result: 25.2647
# Validation result: 26.4056
# ====================================
# Epoch 134
# Loss: 0.144994
# Time: 45.59s
# Test result: 25.3455
# Validation result: 26.2376
# ====================================
# Epoch 135
# Loss: 0.145000
# Time: 45.61s
# Test result: 25.2952
# Validation result: 26.3480
# ====================================
# Epoch 136
# Loss: 0.145056
# Time: 46.96s
# Test result: 25.2516
# Validation result: 26.2640
# ====================================
# Epoch 137
# Loss: 0.144939
# Time: 47.26s
# Test result: 25.3631
# Validation result: 26.3911
# ====================================
# Epoch 138
# Loss: 0.144829
# Time: 45.44s
# Test result: 25.4733
# Validation result: 26.3162
# ====================================
# Epoch 139
# Loss: 0.144604
# Time: 45.10s
# Test result: 25.4972
# Validation result: 26.3712
# ====================================
# Epoch 140
# Loss: 0.144578
# Time: 47.00s
# Test result: 25.3057
# Validation result: 26.5142
# Checkpoint saved to ./model/monochrome/hitomirandom256x256_rl_8x8/2024_12_07_15_55_00/pre-train_epoch_140.pth
# ====================================
# Epoch 141
# Loss: 0.144493
# Time: 46.87s
# Test result: 25.3276
# Validation result: 26.5947
# ====================================
# Epoch 142
# Loss: 0.144543
# Time: 46.66s
# Test result: 25.3216
# Validation result: 26.4309
# ====================================
# Epoch 143
# Loss: 0.144625
# Time: 45.56s
# Test result: 25.4821
# Validation result: 26.5240
# ====================================
# Epoch 144
# Loss: 0.144535
# Time: 43.32s
# Test result: 25.0229
# Validation result: 26.1979
# ====================================
# Epoch 145
# Loss: 0.144299
# Time: 47.12s
# Test result: 25.4194
# Validation result: 26.5159
# ====================================
# Epoch 146
# Loss: 0.144257
# Time: 45.37s
# Test result: 25.2780
# Validation result: 26.3228
# ====================================
# Epoch 147
# Loss: 0.144246
# Time: 46.62s
# Test result: 25.3895
# Validation result: 26.4985
# ====================================
# Epoch 148
# Loss: 0.144157
# Time: 46.71s
# Test result: 25.2680
# Validation result: 26.2964
# ====================================
# Epoch 149
# Loss: 0.144261
# Time: 46.55s
# Test result: 25.5494
# Validation result: 26.6404
# ====================================
# Epoch 150
# Loss: 0.144138
# Time: 47.16s
# Test result: 25.3646
# Validation result: 26.4451
# Checkpoint saved to ./model/monochrome/hitomirandom256x256_rl_8x8/2024_12_07_15_55_00/pre-train_epoch_150.pth
# ====================================
# Epoch 151
# Loss: 0.143820
# Time: 47.03s
# Test result: 25.4190
# Validation result: 26.4831
# ====================================
# Epoch 152
# Loss: 0.143879
# Time: 47.12s
# Test result: 25.1720
# Validation result: 26.0873
# ====================================
# Epoch 153
# Loss: 0.143846
# Time: 47.23s
# Test result: 25.3740
# Validation result: 26.4049
# ====================================
# Epoch 154
# Loss: 0.143784
# Time: 47.21s
# Test result: 25.3395
# Validation result: 26.3601
# ====================================
# Epoch 155
# Loss: 0.143902
# Time: 47.02s
# Test result: 25.4463
# Validation result: 26.4033
# ====================================
# Epoch 156
# Loss: 0.143811
# Time: 46.48s
# Test result: 25.3840
# Validation result: 26.4811
# ====================================
# Epoch 157
# Loss: 0.143489
# Time: 45.67s
# Test result: 25.3203
# Validation result: 26.4307
# ====================================
# Epoch 158
# Loss: 0.143454
# Time: 41.99s
# Test result: 25.2635
# Validation result: 26.4057
# ====================================
# Epoch 159
# Loss: 0.143482
# Time: 42.05s
# Test result: 25.2606
# Validation result: 26.2659
# ====================================
# Epoch 160
# Loss: 0.143395
# Time: 46.58s
# Test result: 25.0773
# Validation result: 26.1163
# Checkpoint saved to ./model/monochrome/hitomirandom256x256_rl_8x8/2024_12_07_15_55_00/pre-train_epoch_160.pth
# ====================================
# Epoch 161
# ...
# Epoch 81
# Loss: 0.158955
# Time: 46.57s
# Test result: 24.6011
# Validation result: 25.7982
# ====================================
# Epoch 82
# Loss: 0.158887
# Time: 47.05s
# Test result: 24.5396
# Validation result: 25.6714
# ====================================
# Epoch 83
# Loss: 0.158950
# Time: 47.36s
# Test result: 24.5464
# Validation result: 25.9416
# ====================================
# Epoch 84
# Loss: 0.158916
# Time: 46.42s
# Test result: 24.5450
# Validation result: 25.7531
# ====================================
# Epoch 85
# Loss: 0.158266
# Time: 43.04s
# Test result: 24.5966
# Validation result: 25.8246
# ====================================
# Epoch 86
# Loss: 0.158482
# Time: 46.05s
# Test result: 24.5536
# Validation result: 25.7794
# ====================================
# Epoch 87
# Loss: 0.158123
# Time: 47.06s
# Test result: 24.6366
# Validation result: 25.7510
# ====================================
# Epoch 88
# Loss: 0.158318
# Time: 42.21s
# Test result: 24.4601
# Validation result: 25.4378
# ====================================
# Epoch 89
# Loss: 0.158293
# Time: 43.41s
# Test result: 24.3819
# Validation result: 25.5390
# ====================================
# Epoch 90
# Loss: 0.158151
# Time: 46.11s
# Test result: 24.4823
# Validation result: 25.6562
# Checkpoint saved to ./model/monochrome/random256x256_udrl_8x8/2024_12_08_21_37_37/pre-train_epoch_90.pth
# ====================================
# Epoch 91
# Loss: 0.157815
# Time: 46.09s
# Test result: 24.7210
# Validation result: 25.8300
# ====================================
# Epoch 92
# Loss: 0.157575
# Time: 47.10s
# Test result: 24.5112
# Validation result: 25.8652
# ====================================
# Epoch 93
# Loss: 0.157641
# Time: 46.80s
# Test result: 24.7728
# Validation result: 25.8274
# ====================================
# Epoch 94
# Loss: 0.157577
# Time: 46.50s
# Test result: 24.5334
# Validation result: 25.9509
# ====================================
# Epoch 95
# Loss: 0.157505
# Time: 46.82s
# Test result: 24.6776
# Validation result: 25.7669
# ====================================
# Epoch 96
# Loss: 0.157525
# Time: 47.44s
# Test result: 24.5425
# Validation result: 25.8583
# ====================================
# Epoch 97
# Loss: 0.157175
# Time: 46.48s
# Test result: 24.8613
# Validation result: 26.0643
# ====================================
# Epoch 98
# Loss: 0.157080
# Time: 46.33s
# Test result: 24.7629
# Validation result: 25.9525
# ====================================
# Epoch 99
# Loss: 0.157061
# Time: 46.28s
# Test result: 24.6919
# Validation result: 25.8461
# ====================================
# Epoch 100
# Loss: 0.156962
# Time: 46.99s
# Test result: 24.5261
# Validation result: 25.8636
# Checkpoint saved to ./model/monochrome/random256x256_udrl_8x8/2024_12_08_21_37_37/pre-train_epoch_100.pth
# ====================================
# Epoch 101
# Loss: 0.156985
# Time: 46.30s
# Test result: 24.4982
# Validation result: 25.8443
# ====================================
# Epoch 102
# Loss: 0.156989
# Time: 46.94s
# Test result: 24.0990
# Validation result: 25.1222
# ====================================
# Epoch 103
# Loss: 0.156864
# Time: 46.75s
# Test result: 24.7364
# Validation result: 26.1126
# ====================================
# Epoch 104
# Loss: 0.156594
# Time: 46.29s
# Test result: 24.4567
# Validation result: 25.7131
# ====================================
# Epoch 105
# Loss: 0.156508
# Time: 46.15s
# Test result: 24.4110
# Validation result: 25.6197
# ====================================
# Epoch 106
# Loss: 0.156407
# Time: 46.75s
# Test result: 24.8253
# Validation result: 26.0042
# ====================================
# Epoch 107
# Loss: 0.156448
# Time: 46.89s
# Test result: 24.6224
# Validation result: 25.9522
# ====================================
# Epoch 108
# Loss: 0.156220
# Time: 46.32s
# Test result: 24.7357
# Validation result: 25.9868
# ====================================
# Epoch 109
# Loss: 0.155803
# Time: 45.80s
# Test result: 24.6785
# Validation result: 25.8639
# ====================================
# Epoch 110
# Loss: 0.156024
# Time: 45.74s
# Test result: 24.6822
# Validation result: 25.7131
# Checkpoint saved to ./model/monochrome/random256x256_udrl_8x8/2024_12_08_21_37_37/pre-train_epoch_110.pth
# ====================================
# Epoch 111
# Loss: 0.155839
# Time: 44.93s
# Test result: 24.5456
# Validation result: 25.8293
# ====================================
# Epoch 112
# Loss: 0.155733
# Time: 46.83s
# Test result: 24.7403
# Validation result: 26.0676
# ====================================
# Epoch 113
# Loss: 0.155895
# Time: 46.93s
# Test result: 24.8358
# Validation result: 26.2843
# ====================================
# Epoch 114
# Loss: 0.155692
# Time: 47.02s
# Test result: 24.7398
# Validation result: 26.1987
# ====================================
# Epoch 115
# Loss: 0.155580
# Time: 46.94s
# Test result: 24.8683
# Validation result: 26.2356
# ====================================
# Epoch 116
# Loss: 0.155375
# Time: 47.12s
# Test result: 24.7245
# Validation result: 26.0947
# ====================================
# Epoch 117
# Loss: 0.155336
# Time: 46.71s
# Test result: 24.7821
# Validation result: 26.0771
# ====================================
# Epoch 118
# Loss: 0.155306
# Time: 46.42s
# Test result: 24.7204
# Validation result: 26.1507
# ====================================
# Epoch 119
# Loss: 0.155378
# Time: 46.69s
# Test result: 24.8445
# Validation result: 25.9207
# ====================================
# Epoch 120
# Loss: 0.155408
# Time: 44.58s
# Test result: 24.7905
# Validation result: 26.0305
# Checkpoint saved to ./model/monochrome/random256x256_udrl_8x8/2024_12_08_21_37_37/pre-train_epoch_120.pth
# ====================================
# Epoch 121
# Loss: 0.154948
# Time: 46.63s
# Test result: 24.8292
# Validation result: 26.0842
# ====================================
# Epoch 122
# Loss: 0.154878
# Time: 46.75s
# Test result: 24.6533
# Validation result: 25.8761
# ====================================
# Epoch 123
# Loss: 0.154852
# Time: 46.90s
# Test result: 24.6469
# Validation result: 26.0756
# ====================================
# Epoch 124
# Loss: 0.154798
# Time: 47.04s
# Test result: 24.8826
# Validation result: 26.0364
# ====================================
# Epoch 125
# Loss: 0.154847
# Time: 46.91s
# Test result: 24.5518
# Validation result: 25.8899
# ====================================
# Epoch 126
# Loss: 0.154846
# Time: 46.95s
# Test result: 24.8112
# Validation result: 26.1192
# ====================================
# Epoch 127
# Loss: 0.154564
# Time: 47.20s
# Test result: 24.5845
# Validation result: 25.6923
# ====================================
# Epoch 128
# Loss: 0.154651
# Time: 46.46s
# Test result: 24.7110
# Validation result: 26.1585
# ====================================
# Epoch 129
# Loss: 0.154244
# Time: 46.73s
# Test result: 24.6870
# Validation result: 26.0872
# ====================================
# Epoch 130
# Loss: 0.154378
# Time: 47.14s
# Test result: 24.6531
# Validation result: 25.9124
# Checkpoint saved to ./model/monochrome/random256x256_udrl_8x8/2024_12_08_21_37_37/pre-train_epoch_130.pth
# ====================================
# Epoch 131
# Loss: 0.154306
# Time: 44.56s
# Test result: 24.7432
# Validation result: 26.0406
# ====================================
# Epoch 132
# Loss: 0.154338
# Time: 46.60s
# Test result: 24.5854
# Validation result: 26.0193
# ====================================
# Epoch 133
# Loss: 0.153923
# Time: 46.57s
# Test result: 24.7316
# Validation result: 26.1057
# ====================================
# Epoch 134
# Loss: 0.154006
# Time: 46.11s
# Test result: 24.9792
# Validation result: 26.2277
# ====================================
# Epoch 135
# Loss: 0.154079
# Time: 47.14s
# Test result: 24.7051
# Validation result: 26.0128
# ====================================
# Epoch 136
# Loss: 0.153916
# Time: 45.37s
# Test result: 24.7724
# Validation result: 26.2036
# ====================================
# Epoch 137
# Loss: 0.153843
# Time: 43.11s
# Test result: 24.9124
# Validation result: 26.1535
# ====================================
# Epoch 138
# Loss: 0.153714
# Time: 46.83s
# Test result: 24.8774
# Validation result: 26.0778
# ====================================
# Epoch 139
# Loss: 0.153567
# Time: 43.29s
# Test result: 24.8766
# Validation result: 26.1366
# ====================================
# Epoch 140
# Loss: 0.153620
# Time: 44.20s
# Test result: 24.7377
# Validation result: 25.8997
# Checkpoint saved to ./model/monochrome/random256x256_udrl_8x8/2024_12_08_21_37_37/pre-train_epoch_140.pth
# ====================================
# Epoch 141
# Loss: 0.153573
# Time: 46.94s
# Test result: 24.8841
# Validation result: 26.1879
# ====================================
# Epoch 142
# Loss: 0.153435
# Time: 46.71s
# Test result: 24.7693
# Validation result: 26.1709
# ====================================
# Epoch 143
# Loss: 0.153263
# Time: 45.95s
# Test result: 24.7894
# Validation result: 26.1987
# ====================================
# Epoch 144
# Loss: 0.153384
# Time: 46.76s
# Test result: 24.6956
# Validation result: 26.2537
# ====================================
# Epoch 145
# Loss: 0.153290
# Time: 46.10s
# Test result: 24.8771
# Validation result: 26.2950
# ====================================
# Epoch 146
# Loss: 0.153076
# Time: 46.83s
# Test result: 24.8667
# Validation result: 26.2399
# ====================================
# Epoch 147
# Loss: 0.153163
# Time: 46.48s
# Test result: 24.7967
# Validation result: 26.2788
# ====================================
# Epoch 148
# Loss: 0.153138
# Time: 41.97s
# Test result: 25.0057
# Validation result: 26.3532
# ====================================
# Epoch 149
# Loss: 0.153138
# Time: 47.18s
# Test result: 24.8214
# Validation result: 26.1774
# ====================================
# Epoch 150
# Loss: 0.153047
# Time: 47.29s
# Test result: 24.8110
# Validation result: 26.3436
# Checkpoint saved to ./model/monochrome/random256x256_udrl_8x8/2024_12_08_21_37_37/pre-train_epoch_150.pth
# ====================================
# Epoch 151
# Loss: 0.152835
# Time: 46.83s
# Test result: 24.8280
# Validation result: 26.2248
# ====================================
# Epoch 152
# Loss: 0.152806
# Time: 46.94s
# Test result: 24.9309
# Validation result: 26.2484
# ====================================
# Epoch 153
# Loss: 0.152699
# Time: 46.60s
# Test result: 24.8276
# Validation result: 26.0665
# ====================================
# Epoch 154
# Loss: 0.152761
# Time: 47.09s
# Test result: 24.9911
# Validation result: 26.4058
# ====================================
# Epoch 155
# Loss: 0.152780
# Time: 46.64s
# Test result: 24.8502
# Validation result: 26.2883
# ====================================
# Epoch 156
# Loss: 0.152698
# Time: 46.54s
# Test result: 24.9861
# Validation result: 26.4063
# ====================================
# Epoch 157
# Loss: 0.152550
# Time: 46.61s
# Test result: 24.9361
# Validation result: 26.1854
# ====================================
# Epoch 158
# Loss: 0.152505
# Time: 44.21s
# Test result: 24.7598
# Validation result: 26.2228
# ====================================
# Epoch 159
# Loss: 0.152268
# Time: 44.65s
# Test result: 25.0950
# Validation result: 26.4176
# ====================================
# Epoch 160
# Loss: 0.152435
# Time: 46.08s
# Test result: 24.8879
# Validation result: 26.3532
# Checkpoint saved to ./model/monochrome/random256x256_udrl_8x8/2024_12_08_21_37_37/pre-train_epoch_160.pth
# ====================================
# Epoch 161
# Loss: 0.152416
# Time: 46.75s
# Test result: 24.9876
# Validation result: 26.3286
# ====================================
# Epoch 162
# Loss: 0.152333
# Time: 47.15s
# Test result: 24.9971
# Validation result: 26.3258
# ====================================
# Epoch 163
# Loss: 0.152234
# Time: 47.21s
# Test result: 24.9939
# Validation result: 26.0881
# ====================================
# Epoch 164
# Loss: 0.152239
# Time: 47.20s
# Test result: 24.9826
# Validation result: 26.3655
# ====================================
# Epoch 165
# Loss: 0.152067
# Time: 47.17s
# Test result: 24.8849
# Validation result: 26.3617
# ====================================
# Epoch 166
# Loss: 0.151938
# Time: 41.77s
# Test result: 24.7999
# Validation result: 26.1428
# ====================================
# Epoch 167
# Loss: 0.152853
# Time: 46.30s
# Test result: 24.9707
# Validation result: 26.4002
# ====================================
# Epoch 168
# Loss: 0.152083
# Time: 47.05s
# Test result: 24.9200
# Validation result: 26.3360
# ====================================
# Epoch 169
# Loss: 0.151861
# Time: 47.02s
# Test result: 24.8959
# Validation result: 26.3421
# ====================================
# Epoch 170
# Loss: 0.151832
# Time: 46.08s
# Test result: 24.9993
# Validation result: 26.2362
# Checkpoint saved to ./model/monochrome/random256x256_udrl_8x8/2024_12_08_21_37_37/pre-train_epoch_170.pth
# ====================================
# Epoch 171
# Loss: 0.151947
# Time: 46.57s
# Test result: 24.8334
# Validation result: 26.1658
# ====================================
# Epoch 172
# Loss: 0.151784
# Time: 44.98s
# Test result: 24.8135
# Validation result: 26.3295
# ====================================
# Epoch 173
# Loss: 0.151707
# Time: 46.48s
# Test result: 24.9092
# Validation result: 26.2262
# ====================================
# Epoch 174
# Loss: 0.151874
# Time: 45.97s
# Test result: 24.9880
# Validation result: 26.1869
# ====================================
# Epoch 175
# Loss: 0.151538
# Time: 46.19s
# Test result: 24.9265
# Validation result: 26.3363
# ====================================
# Epoch 176
# Loss: 0.151478
# Time: 47.17s
# Test result: 24.9416
# Validation result: 26.1730
# ====================================
# Epoch 177
# Loss: 0.151447
# Time: 47.10s
# Test result: 24.7985
# Validation result: 26.1176
# ====================================
# Epoch 178
# Loss: 0.151392
# Time: 47.25s
# Test result: 25.0707
# Validation result: 26.4064
# ====================================
# Epoch 179
# Loss: 0.151456
# Time: 47.23s
# Test result: 24.9067
# Validation result: 26.4001
# ====================================
# Epoch 180
# Loss: 0.151464
# Time: 46.57s
# Test result: 25.0470
# Validation result: 26.5199
# Checkpoint saved to ./model/monochrome/random256x256_udrl_8x8/2024_12_08_21_37_37/pre-train_epoch_180.pth
# ====================================
# Epoch 181
# Loss: 0.151212
# Time: 45.20s
# Test result: 24.9898
# Validation result: 26.3801
# ====================================
# Epoch 182
# Loss: 0.151175
# Time: 46.77s
# Test result: 24.8666
# Validation result: 26.2548
# ====================================
# Epoch 183
# Loss: 0.151182
# Time: 47.20s
# Test result: 24.8839
# Validation result: 26.4569
# ====================================
# Epoch 184
# Loss: 0.151093
# Time: 46.31s
# Test result: 25.1067
# Validation result: 26.6142
# ====================================
# Epoch 185
# Loss: 0.151101
# Time: 46.76s
# Test result: 24.9879
# Validation result: 26.4391
# ====================================
# Epoch 186
# Loss: 0.151101
# Time: 46.76s
# Test result: 24.9527
# Validation result: 26.4412
# ====================================
# Epoch 187
# Loss: 0.151001
# Time: 46.71s
# Test result: 24.9150
# Validation result: 26.2308
# ====================================
# Epoch 188
# Loss: 0.150808
# Time: 47.01s
# Test result: 24.9700
# Validation result: 26.3442
# ====================================
# Epoch 189
# Loss: 0.150911
# Time: 41.63s
# Test result: 25.0047
# Validation result: 26.4902
# ====================================
# Epoch 190
# Loss: 0.150895
# Time: 41.03s
# Test result: 25.0677
# Validation result: 26.6253
# Checkpoint saved to ./model/monochrome/random256x256_udrl_8x8/2024_12_08_21_37_37/pre-train_epoch_190.pth
# ====================================
# Epoch 191
# Loss: 0.150806
# Time: 42.18s
# Test result: 24.9894
# Validation result: 26.2300
# ====================================
# Epoch 192
# Loss: 0.150846
# Time: 41.10s
# Test result: 24.9321
# Validation result: 26.3465
# ====================================
# Epoch 193
# Loss: 0.150767
# Time: 46.02s
# Test result: 25.0507
# Validation result: 26.4751
# ====================================
# Epoch 194
# Loss: 0.150614
# Time: 47.59s
# Test result: 24.9872
# Validation result: 26.4407
# ====================================
# Epoch 195
# Loss: 0.150455
# Time: 45.84s
# Test result: 24.9654
# Validation result: 26.4151
# ====================================
# Epoch 196
# Loss: 0.150557
# Time: 46.64s
# Test result: 25.0514
# Validation result: 26.5548
# ====================================
# Epoch 197
# Loss: 0.150576
# Time: 46.29s
# Test result: 24.9699
# Validation result: 26.3226
# ====================================
# Epoch 198
# Loss: 0.150659
# Time: 46.82s
# Test result: 25.0820
# Validation result: 26.4719
# ====================================
# Epoch 199
# Loss: 0.150288
# Time: 47.03s
# Test result: 25.0981
# Validation result: 26.4953
# ====================================
# Epoch 200
# Loss: 0.150306
# Time: 47.20s
# Test result: 25.1574
# Validation result: 26.6772
# Checkpoint saved to ./model/monochrome/random256x256_udrl_8x8/2024_12_08_21_37_37/pre-train_epoch_200.pth
